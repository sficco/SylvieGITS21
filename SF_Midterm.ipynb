# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib as mlp

# %%
city = ['Seattle','San Francisco','Los Angeles','Denver','Salt Lake City','Phoenix','Chicago','St. Louis','Dallas','Boston','Washington D.C.','Miami','Cresent City','La Grande','Idaho Falls','Yuma','Topeka','St.Cloud','Barnstable','Providence']
TotalDays = [306,314,275,366,366,366,366,366,306,306,366,275,264,366,365,366,366,336,350,366]
PoorDays = [14,22,119,34,21,70,28,10,24,0,3,2,9,9,5,3,4,0,2,4]
aqimed = [42,45,81,58,50,75,56,52,49,42,42,44,32,19,40,44,39,33,35,42]

# %%
alldata2020 = pd.read_csv('alldata2020.csv')

# %%
alldata2020
# Out:
#     Unnamed: 0             City  Total Days  Poor Days  AQImedian      Zone
# 0            0          Seattle         306         14         42      West
# 1            1    San Francisco         314         22         45      West
# 2            2      Los Angeles         275        119         81      West
# 3            3           Denver         366         34         58  Mountain
# 4            4   Salt Lake City         366         21         50  Mountain
# 5            5          Phoenix         366         70         75  Mountain
# 6            6          Chicago         366         28         56   Central
# 7            7        St. Louis         366         10         52   Central
# 8            8           Dallas         306         24         49   Central
# 9            9           Boston         306          0         42      East
# 10          10  Washington D.C.         366          3         42      East
# ...

# %%
alldata2010 = pd.read_csv('data2010.csv')

# %%
alldata2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   City            20 non-null     object
#  1    Total_Days     20 non-null     int64
#  2    Poor_Days      20 non-null     int64
#  3    AQImedian2010  20 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 624.0+ bytes

# %%
alldata2010[' Scale1']= alldata2010[' Total_Days']/365

# %%
alldata = pd.concat([alldata2020, alldata2010], axis=1)

# %%
alldata2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   City            20 non-null     object
#  1    Total_Days     20 non-null     int64
#  2    Poor_Days      20 non-null     int64
#  3    AQImedian2010  20 non-null     int64
#  4    Scale1         20 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 784.0+ bytes

# %%
alldata2010[' Poorday_Rate2010'] = alldata2010[' Poor_Days']/alldata2010[' Scale1']

# %%
alldata['scale']=alldata['Total Days']/365

# %%
alldata2010
# Out:
#                City   Total_Days   Poor_Days   AQImedian2010    Scale1  \
# 0           Seattle          365           3              41  1.000000
# 1     San Francisco          365          14              48  1.000000
# 2       Los Angeles          365         115              77  1.000000
# 3            Denver          365          38              61  1.000000
# 4    Salt Lake City          365          24              51  1.000000
# 5           Phoenix          365          59              74  1.000000
# 6           Chicago          365          43              71  1.000000
# 7         St. Louis          365         103              74  1.000000
# 8            Dallas          365          28              52  1.000000
# 9            Boston          365          10              47  1.000000
# 10  Washington D.C.          365          50              55  1.000000
# 11            Miami          365           6              48  1.000000
# ...

# %%
alldata['Poorday_Rate2020'] = alldata['Poor Days']/alldata['scale']

# %%
alldata
# Out:
#     Unnamed: 0             City  Total Days  Poor Days  AQImedian      Zone  \
# 0            0          Seattle         306         14         42      West
# 1            1    San Francisco         314         22         45      West
# 2            2      Los Angeles         275        119         81      West
# 3            3           Denver         366         34         58  Mountain
# 4            4   Salt Lake City         366         21         50  Mountain
# 5            5          Phoenix         366         70         75  Mountain
# 6            6          Chicago         366         28         56   Central
# 7            7        St. Louis         366         10         52   Central
# 8            8           Dallas         306         24         49   Central
# 9            9           Boston         306          0         42      East
# 10          10  Washington D.C.         366          3         42      East
# ...

# %%
alldata
# Out:
#     Unnamed: 0             City  Total Days  Poor Days  AQImedian      Zone  \
# 0            0          Seattle         306         14         42      West
# 1            1    San Francisco         314         22         45      West
# 2            2      Los Angeles         275        119         81      West
# 3            3           Denver         366         34         58  Mountain
# 4            4   Salt Lake City         366         21         50  Mountain
# 5            5          Phoenix         366         70         75  Mountain
# 6            6          Chicago         366         28         56   Central
# 7            7        St. Louis         366         10         52   Central
# 8            8           Dallas         306         24         49   Central
# 9            9           Boston         306          0         42      East
# 10          10  Washington D.C.         366          3         42      East
# ...

# %%
Poorday_rate2010 = [3,14,115,38,24,59,43,103,28,10,50,6,0,1,0,8,2,2,9,20]
Poorday_rate2020 = [16,25,157,33,20,69,27,9,28,0,2,2,12,8,5,2,3,0,2,3]
width =0.3
plt.bar(np.arange(len(Poorday_rate2010)), Poorday_rate2010, width=width)
plt.bar(np.arange(len(Poorday_rate2020))+ width, Poorday_rate2020, width=width)
plt.title('Poor Day Rate by Year')
plt.legend
plt.xlabel('Year')
plt.ylabel('Poor Day Rate')
plt.show()

# %%
AQImedian2010 = [41,48,77,61,51,74,71,74,52,47,55,48,12,25,43,40,40,36,39,44]
AQImedian = [42,45,81,58,50,75,56,52,49,42,42,44,32,19,40,44,39,33,35,42]
width =0.3
plt.bar(np.arange(len(AQImedian2010)), AQImedian2010, width=width)
plt.bar(np.arange(len(AQImedian))+ width, AQImedian, width=width)
plt.title('AQI Median by Year')
plt.legend
plt.xlabel('Year')
plt.ylabel('AQI Median')
plt.show()
